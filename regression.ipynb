# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### Import dataset

# %%
energy_df=pd.read_csv("energydata_complete (1).csv")
energy_df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %% [markdown]
# #### EXploring the dataset

# %%
### Converting date column to float data type
energy_df=energy_df.replace('[^\date]', "", regex=True).astype(float)
energy_df.describe()
energy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  float64
#  1   Appliances   19735 non-null  float64
#  2   lights       19735 non-null  float64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %% [markdown]
# ### Question 12: R2 value between T2 and T6

# %%
x=energy_df[["T2"]]
y=energy_df[["T6"]]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)
from sklearn.linear_model import LinearRegression
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
predicted_values=linear_model.predict(x_test)

# %%
###R2 score
from sklearn.metrics import r2_score
r2_score=r2_score(y_test,predicted_values)
round(r2_score,2)
# Out:
# 0.63

# %% [markdown]
# ### Normalizing the dataset question 13

# %%
energy_df1=energy_df.drop(columns=["date","lights"])
energy_df1
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0            60.0  19.890000  47.596667  19.200000  44.790000  19.790000
# 1            60.0  19.890000  46.693333  19.200000  44.722500  19.790000
# 2            50.0  19.890000  46.300000  19.200000  44.626667  19.790000
# 3            50.0  19.890000  46.066667  19.200000  44.590000  19.790000
# 4            60.0  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730       100.0  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731        90.0  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732       270.0  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733       420.0  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734       430.0  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaled=pd.DataFrame(scaler.fit_transform(energy_df1),columns=energy_df1.columns)
features_df=energy_df1.drop(columns="Appliances")
target=scaled["Appliances"]

# %% [markdown]
# ### Splitting the datasets into training and test sets
# ### random_state=42

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(features_df,target,test_size=0.3, random_state=42)

# %% [markdown]
# ### Train the model

# %% [markdown]
# ### Question 15-17

# %%
from sklearn.linear_model import LinearRegression
linear_modeL=LinearRegression()
linear_model.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y_pred=linear_model.predict(x1_test)

# %%
### MAE 
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y1_test,y_pred)
round(mae,2)
# Out:
# 0.05

# %%
###RSS
import numpy as np
rss=np.sum(np.square(y1_test-y_pred))
round(rss,2)
# Out:
# 45.35

# %%
###RMSE
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(y1_test,y_pred))
round(rmse,3)
# Out:
# 0.088

# %%
### Coefficient of determination
from sklearn.metrics import r2_score
r2_score=r2_score(y1_test,y_pred)
round(r2_score,2)
# Out:
# 0.15

# %% [markdown]
# ### Question 18

# %% [markdown]
# ### Training a Ridge Regression Model with alpha value of 0.4

# %%
def get_weights_df(model,feat,col_name):
    weights=pd.Series(model.coef_,feat.columns).sort_values()
    weights_df=pd.DataFrame(weights).reset_index()
    weights_df.columns=["Features",col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
from sklearn.linear_model import Ridge
ridge_reg=Ridge(alpha=0.4)
ridge_reg.fit(x1_train,y1_train)
yridge_pred=ridge_reg.predict(x1_test)
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(y1_test,yridge_pred))
round(rmse,3) #No changes in rmse
# Out:
# 0.088

# %% [markdown]
# ### Training a Lasso Regression Model with alpha value of 0.0001
# Question 19 - 20

# %%
from sklearn.linear_model import Lasso
lasso_reg=Lasso(alpha=0.001)
lasso_reg.fit(x1_train,y1_train)
# Out:
# Lasso(alpha=0.001)

# %% [markdown]
# #### non zero feature weights = 5

# %%
def get_weights_df(model,feat,col_name):
    #this function returns the weight of every feature
    weights=pd.Series(model.coef_,feat.columns).sort_values()
    weights_df=pd.DataFrame(weights).reset_index()
    weights_df.columns=["Features",col_name]
    weights_df[col_name].round(3)
    return weights_df

linear_model_weights=get_weights_df(linear_model,x1_train, "Lineear_Model_Weight")
ridge_weights_df=get_weights_df(ridge_reg,x1_train, "Ridge_Weight")
lasso_weights_df=get_weights_df(lasso_reg,x1_train, "Lasso_Weight")

final_weights=pd.merge(linear_model_weights,ridge_weights_df, on="Features")
final_weights=pd.merge(final_weights,lasso_weights_df, on="Features")
final_weights
# Out:
#        Features  Lineear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0            T9             -0.019765     -0.019761 -1.512603e-02
# 1            T2             -0.017168     -0.017164 -9.668148e-03
# 2          RH_2             -0.012842     -0.012840 -9.300608e-03
# 3         T_out             -0.010349     -0.010346 -3.325131e-03
# 4          RH_8             -0.005401     -0.005401 -5.077541e-03
# 5          RH_9             -0.001647     -0.001647 -1.431118e-03
# 6          RH_7             -0.001582     -0.001582 -1.644124e-03
# 7            T5             -0.001496     -0.001497 -1.476185e-03
# 8        RH_out             -0.001022     -0.001022 -1.934555e-05
# 9            T1             -0.000346     -0.000347 -0.000000e+00
# 10          rv1              0.000015      0.000015  2.132002e-05
# 11          rv2              0.000015      0.000015  3.028963e-19
# 12  Press_mm_hg              0.000159      0.000159  6.963612e-05
# ...

# %%
from sklearn.linear_model import Lasso
lasso_reg=Lasso(alpha=0.001)
lasso_reg.fit(x1_train,y1_train)
ylasso_predict=lasso_reg.predict(x1_test)

# %%
from sklearn.metrics import mean_squared_error 
rmse=np.sqrt(mean_squared_error(y1_test,ylasso_predict))
round(rmse,3)
# Out:
# 0.088
